# %% [markdown]
# <span style="font-size:50px"><strong>ML4HC Project 1 - Task 1</strong></span>

# %% [markdown]
# # Data loading - Q1.1

# %% [markdown]
# ### Create Parquet file Q1.1

# %%
import os
import pandas as pd
import numpy as np
from glob import glob
from tqdm import tqdm
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler    


# Define paths
data_dir = "./data/"

pd.set_option('display.max_columns', None)

def read_patient_data(file_path):
    df = pd.read_csv(file_path, sep=",")
    return df

# Process each patient file
def process_patient_data(patient_file):
    df = read_patient_data(patient_file)

    df['Time'] = pd.to_timedelta(df['Time'] + ':00')
    df['Time'] = df['Time'].dt.ceil('h')
    df['Time'] = df['Time'].dt.total_seconds() // 3600
    
    return df

def generate_parquet(letter:str, keepICUType=False):

    folder_path = data_dir + "set-" + letter
    static_columns = ["RecordID", "Age", "Gender", "Height", "ICUType", "Weight"] #ICU-Type can be dropped later
    df_processed = pd.DataFrame()

    for file_name in tqdm(os.listdir(folder_path)):
        file_path = os.path.join(folder_path, file_name)
        try:
            df = process_patient_data(file_path)
        except:
            print("Could not read file"+file_name)
            continue
        df = df.pivot_table(index="Time", columns="Parameter", values="Value", aggfunc="last").reset_index()
        df = df.reindex(columns= ["Time"] + static_columns + [col for col in df.columns if col not in static_columns + ["Time"]])
        df.set_index('Time', inplace=True)
        df = df.reindex(range(49), fill_value=np.nan)
        df[static_columns] = df[static_columns].ffill().bfill()
        df.reset_index(drop=False, inplace=True)
        df_processed = pd.concat([df_processed, df], ignore_index=True)

    if not keepICUType:
        df_processed = df_processed.drop(columns=["ICUType"])

    df_target = read_patient_data(data_dir+f"Outcomes-{letter}.txt")
    df_target = df_target[['RecordID', 'In-hospital_death']]
    df_processed = df_processed.merge(df_target, on="RecordID", how="left")

    df_processed.to_parquet(f"data_{letter}_raw.parquet", engine="pyarrow", index=False)

    return df_processed

# %%
for letter in ["a","b","c"]:
    generate_parquet(letter,keepICUType=True)
# Out:
# 100%|██████████| 4000/4000 [01:36<00:00, 41.50it/s]
# 100%|██████████| 4000/4000 [02:17<00:00, 29.18it/s]
# 100%|██████████| 4000/4000 [02:19<00:00, 28.66it/s]

# %% [markdown]
# ### Show Data

# %%
letter="a"
df = pd.read_parquet(f"data_{letter}_raw.parquet")
print(df.shape)
df.head()
# Out:
# (196000, 44)
#    Time  RecordID   Age  Gender  Height  ICUType  Weight   BUN  Creatinine  \
# 0     0  132592.0  35.0     0.0    -1.0      3.0    71.8   NaN         NaN
# 1     1  132592.0  35.0     0.0    -1.0      3.0    71.8   NaN         NaN
# 2     2  132592.0  35.0     0.0    -1.0      3.0    71.8   NaN         NaN
# 3     3  132592.0  35.0     0.0    -1.0      3.0    71.8  68.0         2.3
# 4     4  132592.0  35.0     0.0    -1.0      3.0    71.8   NaN         NaN
#
#     GCS  Glucose  HCO3   HCT     HR    K   Mg  NIDiasABP  NIMAP  NISysABP  \
# 0   NaN      NaN   NaN   NaN    NaN  NaN  NaN        NaN    NaN       NaN
# 1   NaN      NaN   NaN   NaN    NaN  NaN  NaN        NaN    NaN       NaN
# 2  15.0      NaN   NaN   NaN  112.0  NaN  NaN       43.0  68.67     120.0
# 3   NaN    603.0  11.0  25.5  113.0  5.3  2.8       53.0  76.67     124.0
# 4   NaN      NaN   NaN   NaN  112.0  NaN  NaN       48.0  71.33     118.0
#
#       Na  Platelets  RespRate  Temp  TroponinT  Urine   WBC  ALP  ALT  AST  \
# 0    NaN        NaN       NaN   NaN        NaN    NaN   NaN  NaN  NaN  NaN
# 1    NaN        NaN       NaN   NaN        NaN    NaN   NaN  NaN  NaN  NaN
# 2    NaN        NaN      22.0  36.6        NaN    NaN   NaN  NaN  NaN  NaN
# 3  140.0      287.0      21.0   NaN       0.15  120.0  15.3  NaN  NaN  NaN
# 4    NaN        NaN      24.0   NaN        NaN   60.0   NaN  NaN  NaN  NaN
#
#    Albumin  Bilirubin  FiO2  MechVent  PaCO2  PaO2  pH  DiasABP  MAP  SaO2  \
# 0      NaN        NaN   NaN       NaN    NaN   NaN NaN      NaN  NaN   NaN
# 1      NaN        NaN   NaN       NaN    NaN   NaN NaN      NaN  NaN   NaN
# 2      NaN        NaN   NaN       NaN    NaN   NaN NaN      NaN  NaN   NaN
# 3      NaN        NaN   NaN       NaN    NaN   NaN NaN      NaN  NaN   NaN
# 4      NaN        NaN   NaN       NaN    NaN   NaN NaN      NaN  NaN   NaN
#
#    SysABP  Lactate  Cholesterol  TroponinI  In-hospital_death
# 0     NaN      NaN          NaN        NaN                  0
# 1     NaN      NaN          NaN        NaN                  0
# 2     NaN      NaN          NaN        NaN                  0
# 3     NaN      NaN          NaN        NaN                  0
# 4     NaN      NaN          NaN        NaN                  0

# %% [markdown]
# # Data exploration and  cleaning - Q1.2

# %% [markdown]
# ##### Display ranges for all variables

# %%
def print_combined_min_max(data_type="raw"):
    combined_min_max = {}

    for letter in ["a", "b", "c"]:
        df = pd.read_parquet(f"data_{letter}_{data_type}.parquet")
        for var in df.columns:
            col = df[var]
            if pd.api.types.is_numeric_dtype(col):
                min_val = col.min(skipna=True)
                max_val = col.max(skipna=True)
                if var not in combined_min_max:
                    combined_min_max[var] = [min_val, max_val]
                else:
                    combined_min_max[var][0] = min(combined_min_max[var][0], min_val)
                    combined_min_max[var][1] = max(combined_min_max[var][1], max_val)

    for var, (min_val, max_val) in combined_min_max.items():
        print(f"{var}:{min_val}-{max_val}")

# %%
print_combined_min_max("raw")
# Out:
# Time:0-48
# RecordID:132539.0-163037.0
# Age:15.0-90.0
# Gender:-1.0-1.0
# Height:-1.0-462.3
# ICUType:1.0-4.0
# Weight:-1.0-472.0
# BUN:0.0-209.0
# Creatinine:0.1-22.1
# GCS:3.0-15.0
# Glucose:8.0-1591.0
# HCO3:5.0-52.0
# HCT:5.0-61.8
# HR:0.0-300.0
# K:1.5-22.9
# Mg:0.0-37.5
# NIDiasABP:-1.0-180.0
# NIMAP:0.0-228.0
# NISysABP:0.0-300.0
# Na:98.0-180.0
# Platelets:5.0-2292.0
# RespRate:0.0-100.0
# Temp:-17.8-42.2
# TroponinT:0.01-29.91
# Urine:0.0-11000.0
# WBC:0.0-528.0
# ALP:8.0-4695.0
# ALT:1.0-16920.0
# AST:4.0-36400.0
# Albumin:1.0-5.3
# Bilirubin:0.0-82.8
# FiO2:0.21-1.0
# MechVent:1.0-1.0
# PaCO2:0.0-100.0
# PaO2:0.0-500.0
# pH:0.0-735.0
# DiasABP:-1.0-272.0
# MAP:0.0-299.0
# SaO2:0.0-100.0
# SysABP:0.0-285.0
# Lactate:0.0-31.0
# Cholesterol:28.0-362.0
# TroponinI:0.1-49.6
# In-hospital_death:0-1

# %% [markdown]
# ##### Remove measurement errors

# %%
for letter in ["a", "b", "c"]:
    ##Forwardfill and impute
    df = pd.read_parquet(f"data_{letter}_raw.parquet")
    print(df.head())

    ##Remove negatives that are NaN values
    df['Height'] = df['Height'].replace(-1.0, np.nan)
    df['Weight'] = df['Weight'].replace(-1.0, np.nan)
    df['Gender'] = df['Gender'].replace(-1.0, np.nan)
    df['DiasABP'] = df['DiasABP'].replace(-1.0, np.nan)
    df['NIDiasABP'] = df['NIDiasABP'].replace(-1.0, np.nan)

    # Double checked all of these
    # Remove erroneous values of 0 that do not make medical sense  
    df['NIDiasABP'] = df['NIDiasABP'].replace(0.0, np.nan)
    df['DiasABP'] = df['DiasABP'].replace(0.0, np.nan)
    df['BUN'] = df['BUN'].replace(0.0, np.nan)
    df['HR'] = df['HR'].replace(0.0, np.nan)
    df['NIMAP'] = df['NIMAP'].replace(0, np.nan)
    df['NISysABP'] = df['NISysABP'].replace(0, np.nan)
    df['RespRate'] = df['RespRate'].replace(0, np.nan)
    df['PaCO2'] = df['PaCO2'].replace(0, np.nan)
    df['PaO2'] = df['PaO2'].replace(0, np.nan)
    df['MAP'] = df['MAP'].replace(0, np.nan)
    df['Bilirubin'] = df['Bilirubin'].replace(0, np.nan)
    df['SysABP'] = df['SysABP'].replace(0, np.nan)
    df['Mg'] = df['Mg'].replace(0, np.nan)
    df['SaO2'] = df['SaO2'].replace(0, np.nan)
    df['WBC'] = df['WBC'].replace(0, np.nan)
    df['Lactate'] = df['Lactate'].replace(0, np.nan)

    # Remove erroneous values   (measurement errors)
    df.loc[df['Temp'] < 30, 'Temp'] = np.nan # body temperatures <30deg doesnt happen
    df.loc[df['Height'] < 20, 'Height'] = np.nan # these are adults 
    df.loc[df['Height'] > 250, 'Height'] = np.nan # larger than largest person
    df.loc[df['Weight'] < 20, 'Weight'] = np.nan  # adults 

    
    #Very likely wrong
    df['Weight'] = df['Weight'].replace(472.0, np.nan)
    df.loc[df['pH'] < 6, 'pH'] = np.nan
    df.loc[df['pH'] > 9, 'pH'] = np.nan
    df.loc[df['Mg'] > 20, 'Mg'] = np.nan
    df.loc[df['K'] > 20, 'K'] = np.nan
    
    df.loc[df['MechVent']==np.nan, 'MechVent'] = 0.0 # fill in NaN values with 0.0 for MechVent
    #df = df.drop(columns=["MechVent"]) # Only values of 1.0 here
    print(df.head())


    df.to_parquet(f"data_{letter}_cleaned.parquet", engine="pyarrow", index=False)
# Out:
#    Time  RecordID   Age  Gender  Height  ICUType  Weight  BUN  Creatinine  \
# 0     0  132539.0  54.0     0.0    -1.0      4.0    -1.0  NaN         NaN
# 1     1  132539.0  54.0     0.0    -1.0      4.0    -1.0  NaN         NaN
# 2     2  132539.0  54.0     0.0    -1.0      4.0    -1.0  NaN         NaN
# 3     3  132539.0  54.0     0.0    -1.0      4.0    -1.0  NaN         NaN
# 4     4  132539.0  54.0     0.0    -1.0      4.0    -1.0  NaN         NaN
#
#     GCS  Glucose  HCO3   HCT    HR   K  Mg  NIDiasABP  NIMAP  NISysABP  Na  \
# 0   NaN      NaN   NaN   NaN   NaN NaN NaN        NaN    NaN       NaN NaN
# 1  15.0      NaN   NaN   NaN  77.0 NaN NaN       58.0  91.00     157.0 NaN
# 2   NaN      NaN   NaN   NaN  60.0 NaN NaN       62.0  87.00     137.0 NaN
# 3   NaN      NaN   NaN   NaN  62.0 NaN NaN       52.0  75.67     123.0 NaN
# 4  15.0      NaN   NaN  33.7  80.0 NaN NaN       52.0  72.67     114.0 NaN
#
#    Platelets  RespRate  Temp  Urine  WBC  DiasABP  FiO2  MAP  MechVent  PaCO2  \
# 0        NaN       NaN   NaN    NaN  NaN      NaN   NaN  NaN       NaN    NaN
# 1        NaN      19.0  35.6   60.0  NaN      NaN   NaN  NaN       NaN    NaN
# 2        NaN      18.0   NaN   30.0  NaN      NaN   NaN  NaN       NaN    NaN
# 3        NaN      19.0   NaN  170.0  NaN      NaN   NaN  NaN       NaN    NaN
# 4        NaN      20.0  37.8   60.0  NaN      NaN   NaN  NaN       NaN    NaN
#
#    PaO2  SaO2  SysABP  pH  ALP  ALT  AST  Albumin  Bilirubin  Lactate  \
# 0   NaN   NaN     NaN NaN  NaN  NaN  NaN      NaN        NaN      NaN
# 1   NaN   NaN     NaN NaN  NaN  NaN  NaN      NaN        NaN      NaN
# 2   NaN   NaN     NaN NaN  NaN  NaN  NaN      NaN        NaN      NaN
# 3   NaN   NaN     NaN NaN  NaN  NaN  NaN      NaN        NaN      NaN
# 4   NaN   NaN     NaN NaN  NaN  NaN  NaN      NaN        NaN      NaN
#
#    Cholesterol  TroponinI  TroponinT  In-hospital_death
# 0          NaN        NaN        NaN                  0
# 1          NaN        NaN        NaN                  0
# 2          NaN        NaN        NaN                  0
# 3          NaN        NaN        NaN                  0
# 4          NaN        NaN        NaN                  0
#    Time  RecordID   Age  Gender  Height  ICUType  Weight  BUN  Creatinine  \
# 0     0  132539.0  54.0     0.0     NaN      4.0     NaN  NaN         NaN
# 1     1  132539.0  54.0     0.0     NaN      4.0     NaN  NaN         NaN
# 2     2  132539.0  54.0     0.0     NaN      4.0     NaN  NaN         NaN
# 3     3  132539.0  54.0     0.0     NaN      4.0     NaN  NaN         NaN
# 4     4  132539.0  54.0     0.0     NaN      4.0     NaN  NaN         NaN
#
#     GCS  Glucose  HCO3   HCT    HR   K  Mg  NIDiasABP  NIMAP  NISysABP  Na  \
# 0   NaN      NaN   NaN   NaN   NaN NaN NaN        NaN    NaN       NaN NaN
# 1  15.0      NaN   NaN   NaN  77.0 NaN NaN       58.0  91.00     157.0 NaN
# 2   NaN      NaN   NaN   NaN  60.0 NaN NaN       62.0  87.00     137.0 NaN
# 3   NaN      NaN   NaN   NaN  62.0 NaN NaN       52.0  75.67     123.0 NaN
# 4  15.0      NaN   NaN  33.7  80.0 NaN NaN       52.0  72.67     114.0 NaN
#
#    Platelets  RespRate  Temp  Urine  WBC  DiasABP  FiO2  MAP  MechVent  PaCO2  \
# 0        NaN       NaN   NaN    NaN  NaN      NaN   NaN  NaN       NaN    NaN
# 1        NaN      19.0  35.6   60.0  NaN      NaN   NaN  NaN       NaN    NaN
# 2        NaN      18.0   NaN   30.0  NaN      NaN   NaN  NaN       NaN    NaN
# 3        NaN      19.0   NaN  170.0  NaN      NaN   NaN  NaN       NaN    NaN
# 4        NaN      20.0  37.8   60.0  NaN      NaN   NaN  NaN       NaN    NaN
#
#    PaO2  SaO2  SysABP  pH  ALP  ALT  AST  Albumin  Bilirubin  Lactate  \
# 0   NaN   NaN     NaN NaN  NaN  NaN  NaN      NaN        NaN      NaN
# 1   NaN   NaN     NaN NaN  NaN  NaN  NaN      NaN        NaN      NaN
# 2   NaN   NaN     NaN NaN  NaN  NaN  NaN      NaN        NaN      NaN
# 3   NaN   NaN     NaN NaN  NaN  NaN  NaN      NaN        NaN      NaN
# 4   NaN   NaN     NaN NaN  NaN  NaN  NaN      NaN        NaN      NaN
#
#    Cholesterol  TroponinI  TroponinT  In-hospital_death
# 0          NaN        NaN        NaN                  0
# 1          NaN        NaN        NaN                  0
# 2          NaN        NaN        NaN                  0
# 3          NaN        NaN        NaN                  0
# 4          NaN        NaN        NaN                  0
#    Time  RecordID   Age  Gender  Height  ICUType  Weight  ALP  ALT  AST  \
# 0     0  142675.0  70.0     1.0   175.3      2.0    85.0  NaN  NaN  NaN
# 1     1  142675.0  70.0     1.0   175.3      2.0    85.0  NaN  NaN  NaN
# 2     2  142675.0  70.0     1.0   175.3      2.0    85.0  NaN  NaN  NaN
# 3     3  142675.0  70.0     1.0   175.3      2.0    85.0  NaN  NaN  NaN
# 4     4  142675.0  70.0     1.0   175.3      2.0    85.0  NaN  NaN  NaN
#
#    Albumin   BUN  Bilirubin  Creatinine  DiasABP  FiO2  GCS  Glucose  HCO3  \
# 0      NaN   NaN        NaN         NaN      NaN   NaN  NaN      NaN   NaN
# 1      NaN   NaN        NaN         NaN      NaN   NaN  NaN      NaN   NaN
# 2      NaN   NaN        NaN         NaN     84.0   1.0  3.0      NaN   NaN
# 3      NaN  13.0        NaN         0.8     70.0   0.5  NaN      NaN  22.0
# 4      NaN   NaN        NaN         NaN     44.0   NaN  NaN      NaN   NaN
#
#     HCT    HR   K  Lactate    MAP  MechVent  Mg  Na  PaCO2   PaO2  Platelets  \
# 0   NaN   NaN NaN      NaN    NaN       NaN NaN NaN    NaN    NaN        NaN
# 1   NaN   NaN NaN      NaN    NaN       NaN NaN NaN   32.0  378.0        NaN
# 2   NaN  76.0 NaN      NaN  108.0       1.0 NaN NaN   25.0  331.0        NaN
# 3  33.7  85.0 NaN      NaN   89.0       1.0 NaN NaN    NaN    NaN      185.0
# 4   NaN  76.0 NaN      NaN   51.0       NaN NaN NaN   33.0  208.0        NaN
#
#    SaO2  SysABP  Temp  Urine  WBC    pH  NIDiasABP  NIMAP  NISysABP  RespRate  \
# 0   NaN     NaN   NaN    NaN  NaN   NaN        NaN    NaN       NaN       NaN
# 1   NaN     NaN   NaN    NaN  NaN  7.50        NaN    NaN       NaN       NaN
# 2   NaN   149.0  35.7  200.0  NaN  7.50        NaN    NaN       NaN       NaN
# 3   NaN   126.0  35.7  280.0  NaN   NaN        NaN    NaN       NaN       NaN
# 4   NaN    69.0  34.9  230.0  NaN  7.43        NaN    NaN       NaN       NaN
#
#    TroponinT  Cholesterol  TroponinI  In-hospital_death
# 0        NaN          NaN        NaN                  1
# 1        NaN          NaN        NaN                  1
# 2        NaN          NaN        NaN                  1
# 3        NaN          NaN        NaN                  1
# 4        NaN          NaN        NaN                  1
#    Time  RecordID   Age  Gender  Height  ICUType  Weight  ALP  ALT  AST  \
# 0     0  142675.0  70.0     1.0   175.3      2.0    85.0  NaN  NaN  NaN
# 1     1  142675.0  70.0     1.0   175.3      2.0    85.0  NaN  NaN  NaN
# 2     2  142675.0  70.0     1.0   175.3      2.0    85.0  NaN  NaN  NaN
# 3     3  142675.0  70.0     1.0   175.3      2.0    85.0  NaN  NaN  NaN
# 4     4  142675.0  70.0     1.0   175.3      2.0    85.0  NaN  NaN  NaN
#
#    Albumin   BUN  Bilirubin  Creatinine  DiasABP  FiO2  GCS  Glucose  HCO3  \
# 0      NaN   NaN        NaN         NaN      NaN   NaN  NaN      NaN   NaN
# 1      NaN   NaN        NaN         NaN      NaN   NaN  NaN      NaN   NaN
# 2      NaN   NaN        NaN         NaN     84.0   1.0  3.0      NaN   NaN
# 3      NaN  13.0        NaN         0.8     70.0   0.5  NaN      NaN  22.0
# 4      NaN   NaN        NaN         NaN     44.0   NaN  NaN      NaN   NaN
#
#     HCT    HR   K  Lactate    MAP  MechVent  Mg  Na  PaCO2   PaO2  Platelets  \
# 0   NaN   NaN NaN      NaN    NaN       NaN NaN NaN    NaN    NaN        NaN
# 1   NaN   NaN NaN      NaN    NaN       NaN NaN NaN   32.0  378.0        NaN
# 2   NaN  76.0 NaN      NaN  108.0       1.0 NaN NaN   25.0  331.0        NaN
# 3  33.7  85.0 NaN      NaN   89.0       1.0 NaN NaN    NaN    NaN      185.0
# 4   NaN  76.0 NaN      NaN   51.0       NaN NaN NaN   33.0  208.0        NaN
#
#    SaO2  SysABP  Temp  Urine  WBC    pH  NIDiasABP  NIMAP  NISysABP  RespRate  \
# 0   NaN     NaN   NaN    NaN  NaN   NaN        NaN    NaN       NaN       NaN
# 1   NaN     NaN   NaN    NaN  NaN  7.50        NaN    NaN       NaN       NaN
# 2   NaN   149.0  35.7  200.0  NaN  7.50        NaN    NaN       NaN       NaN
# 3   NaN   126.0  35.7  280.0  NaN   NaN        NaN    NaN       NaN       NaN
# 4   NaN    69.0  34.9  230.0  NaN  7.43        NaN    NaN       NaN       NaN
#
#    TroponinT  Cholesterol  TroponinI  In-hospital_death
# 0        NaN          NaN        NaN                  1
# 1        NaN          NaN        NaN                  1
# 2        NaN          NaN        NaN                  1
# 3        NaN          NaN        NaN                  1
# 4        NaN          NaN        NaN                  1
#    Time  RecordID   Age  Gender  Height  ICUType  Weight  ALP  ALT  AST  \
# 0     0  152871.0  71.0     1.0   167.6      4.0    79.2  NaN  NaN  NaN
# 1     1  152871.0  71.0     1.0   167.6      4.0    79.2  NaN  NaN  NaN
# 2     2  152871.0  71.0     1.0   167.6      4.0    79.2  NaN  NaN  NaN
# 3     3  152871.0  71.0     1.0   167.6      4.0    79.2  NaN  NaN  NaN
# 4     4  152871.0  71.0     1.0   167.6      4.0    79.2  NaN  NaN  NaN
#
#    Albumin   BUN  Bilirubin  Creatinine  DiasABP  FiO2  GCS  Glucose  HCO3  \
# 0      NaN   NaN        NaN         NaN      NaN   NaN  NaN      NaN   NaN
# 1      NaN   NaN        NaN         NaN     59.0   0.4  NaN      NaN   NaN
# 2      NaN  36.0        NaN         3.7     58.0   NaN  9.0     84.0  20.0
# 3      NaN   NaN        NaN         NaN     59.0   NaN  NaN      NaN   NaN
# 4      NaN   NaN        NaN         NaN      NaN   0.4  NaN      NaN   NaN
#
#    HCT    HR    K  Lactate   MAP  MechVent   Mg     Na  PaCO2  PaO2  \
# 0  NaN   NaN  NaN      NaN   NaN       NaN  NaN    NaN    NaN   NaN
# 1  NaN  65.0  NaN      NaN  92.0       1.0  NaN    NaN    NaN   NaN
# 2  NaN  66.0  4.2      NaN  91.0       NaN  2.0  140.0    NaN   NaN
# 3  NaN  66.0  NaN      NaN  92.0       NaN  NaN    NaN   42.0  98.0
# 4  NaN   NaN  NaN      NaN   NaN       1.0  NaN    NaN    NaN   NaN
#
#    Platelets  SysABP  Temp  Urine  WBC    pH  NIDiasABP  NIMAP  NISysABP  \
# 0        NaN     NaN   NaN    NaN  NaN   NaN        NaN    NaN       NaN
# 1        NaN   154.0   NaN    NaN  NaN   NaN        NaN    NaN       NaN
# 2        NaN   152.0  37.4    NaN  NaN   NaN        NaN    NaN       NaN
# 3        NaN   154.0  37.4   15.0  NaN  7.34        NaN    NaN       NaN
# 4        NaN     NaN   NaN    NaN  NaN   NaN        NaN    NaN       NaN
#
#    RespRate  SaO2  TroponinT  Cholesterol  TroponinI  In-hospital_death
# 0       NaN   NaN        NaN          NaN        NaN                  0
# 1       NaN   NaN        NaN          NaN        NaN                  0
# 2       NaN   NaN        NaN          NaN        NaN                  0
# 3       NaN   NaN        NaN          NaN        NaN                  0
# 4       NaN   NaN        NaN          NaN        NaN                  0
#    Time  RecordID   Age  Gender  Height  ICUType  Weight  ALP  ALT  AST  \
# 0     0  152871.0  71.0     1.0   167.6      4.0    79.2  NaN  NaN  NaN
# 1     1  152871.0  71.0     1.0   167.6      4.0    79.2  NaN  NaN  NaN
# 2     2  152871.0  71.0     1.0   167.6      4.0    79.2  NaN  NaN  NaN
# 3     3  152871.0  71.0     1.0   167.6      4.0    79.2  NaN  NaN  NaN
# 4     4  152871.0  71.0     1.0   167.6      4.0    79.2  NaN  NaN  NaN
#
#    Albumin   BUN  Bilirubin  Creatinine  DiasABP  FiO2  GCS  Glucose  HCO3  \
# 0      NaN   NaN        NaN         NaN      NaN   NaN  NaN      NaN   NaN
# 1      NaN   NaN        NaN         NaN     59.0   0.4  NaN      NaN   NaN
# 2      NaN  36.0        NaN         3.7     58.0   NaN  9.0     84.0  20.0
# 3      NaN   NaN        NaN         NaN     59.0   NaN  NaN      NaN   NaN
# 4      NaN   NaN        NaN         NaN      NaN   0.4  NaN      NaN   NaN
#
#    HCT    HR    K  Lactate   MAP  MechVent   Mg     Na  PaCO2  PaO2  \
# 0  NaN   NaN  NaN      NaN   NaN       NaN  NaN    NaN    NaN   NaN
# 1  NaN  65.0  NaN      NaN  92.0       1.0  NaN    NaN    NaN   NaN
# 2  NaN  66.0  4.2      NaN  91.0       NaN  2.0  140.0    NaN   NaN
# 3  NaN  66.0  NaN      NaN  92.0       NaN  NaN    NaN   42.0  98.0
# 4  NaN   NaN  NaN      NaN   NaN       1.0  NaN    NaN    NaN   NaN
#
#    Platelets  SysABP  Temp  Urine  WBC    pH  NIDiasABP  NIMAP  NISysABP  \
# 0        NaN     NaN   NaN    NaN  NaN   NaN        NaN    NaN       NaN
# 1        NaN   154.0   NaN    NaN  NaN   NaN        NaN    NaN       NaN
# 2        NaN   152.0  37.4    NaN  NaN   NaN        NaN    NaN       NaN
# 3        NaN   154.0  37.4   15.0  NaN  7.34        NaN    NaN       NaN
# 4        NaN     NaN   NaN    NaN  NaN   NaN        NaN    NaN       NaN
#
#    RespRate  SaO2  TroponinT  Cholesterol  TroponinI  In-hospital_death
# 0       NaN   NaN        NaN          NaN        NaN                  0
# 1       NaN   NaN        NaN          NaN        NaN                  0
# 2       NaN   NaN        NaN          NaN        NaN                  0
# 3       NaN   NaN        NaN          NaN        NaN                  0
# 4       NaN   NaN        NaN          NaN        NaN                  0

# %%
print_combined_min_max(data_type="cleaned")
# Out:
# Time:0-48
# RecordID:132539.0-163037.0
# Age:15.0-90.0
# Gender:0.0-1.0
# Height:121.9-210.8
# ICUType:1.0-4.0
# Weight:21.7-300.0
# BUN:1.0-209.0
# Creatinine:0.1-22.1
# GCS:3.0-15.0
# Glucose:8.0-1591.0
# HCO3:5.0-52.0
# HCT:5.0-61.8
# HR:3.4-300.0
# K:1.5-19.6
# Mg:0.4-19.5
# NIDiasABP:6.0-180.0
# NIMAP:0.2-228.0
# NISysABP:0.15-300.0
# Na:98.0-180.0
# Platelets:5.0-2292.0
# RespRate:1.0-100.0
# Temp:30.0-42.2
# Urine:0.0-11000.0
# WBC:0.1-528.0
# DiasABP:3.0-272.0
# FiO2:0.21-1.0
# MAP:1.0-299.0
# MechVent:1.0-1.0
# PaCO2:0.3-100.0
# PaO2:7.47-500.0
# SaO2:1.06-100.0
# SysABP:3.0-285.0
# pH:6.76-7.72
# ALP:8.0-4695.0
# ALT:1.0-16920.0
# AST:4.0-36400.0
# Albumin:1.0-5.3
# Bilirubin:0.1-82.8
# Lactate:0.3-31.0
# Cholesterol:28.0-362.0
# TroponinI:0.1-49.6
# TroponinT:0.01-29.91
# In-hospital_death:0-1

# %% [markdown]
# ## Plot histograms

# %% [markdown]
# TBD: Generate nicer Plots Q1.2

# %% [markdown]
# Binning for plotting

# %%
# this probabily is broken now cause i changed the column order by accident
df = pd.read_parquet(f"data_a_raw.parquet")
bins_specific = [36]*df.columns.shape[0]
bins_specific[0] = 49
bins_specific[11] = 12
bins_specific[10] = 10
bins_specific[29] = 10


bins_general = [200]*df.columns.shape[0]

# %% [markdown]
# #### Plot combined data (a,b,c) individually by variable

# %%
def plot_histograms(bins, data_type="raw", use_log=False):
    df_all = pd.concat([pd.read_parquet(f"data_{l}_{data_type}.parquet") for l in ["a", "b", "c"]], ignore_index=True)
    if use_log:
        df_all = np.log(df_all + 1e-9)

    for i in range(0, len(df_all.columns), 2):
        fig, ax = plt.subplots(1, 2, figsize=(14, 4))
        for j in range(2):
            if i + j >= len(df_all.columns):
                break
            var = df_all.columns[i + j]
            ax[j].hist(df_all[var].dropna(), bins=bins[i + j])
            ax[j].set_title(f"{i + j}: Histogram of {var}")
            ax[j].set_xlabel(var)
            ax[j].set_ylabel("Frequency")
        plt.show()
        plt.close(fig)

# %%
plot_histograms(bins_general, "cleaned")

# %% [markdown]
# Data description:
#
# Continuous 41
# Categorical: Gender(43)...

# %% [markdown]
# Remove ICU type

# %%
vars = list(df.columns)
print(vars)
dem_vars = vars[2:4]
print(dem_vars)
ts_vars = vars[4:42].remove('ICUType')
print(ts_vars)
# Out:
# ['Time', 'RecordID', 'Age', 'Gender', 'Height', 'ICUType', 'Weight', 'BUN', 'Creatinine', 'GCS', 'Glucose', 'HCO3', 'HCT', 'HR', 'K', 'Mg', 'NIDiasABP', 'NIMAP', 'NISysABP', 'Na', 'Platelets', 'RespRate', 'Temp', 'Urine', 'WBC', 'DiasABP', 'FiO2', 'MAP', 'MechVent', 'PaCO2', 'PaO2', 'SaO2', 'SysABP', 'pH', 'ALP', 'ALT', 'AST', 'Albumin', 'Bilirubin', 'Lactate', 'Cholesterol', 'TroponinI', 'TroponinT', 'In-hospital_death']
# ['Age', 'Gender']
# None

# %% [markdown]
# #### Plot by categorical variables

# %%
df_all = pd.concat([pd.read_parquet(f"data_{l}_cleaned.parquet") for l in ["a", "b", "c"]], ignore_index=True)

ts_vars = ts_vars = [var for var in list(df_all.columns)[4:42] if var != 'ICUType']
for i, var in enumerate(ts_vars):
    fig, ax = plt.subplots(1, 2, figsize=(14, 3)) # Create a figure and an axes object
    for j in range(0,7):
        binstart = j*10 + 16
        agegroup = df_all.loc[(df_all["Age"] >= binstart) & (df_all["Age"] < binstart + 10), var]
        ax[0].hist(agegroup, alpha=0.4, density=True, bins=bins_specific[i])  # Plot the histogram on the axes
    ax[0].set_title(f"{i}: Histogram of {var} per age group")  # Set the title
    ax[0].set_xlabel(var)  # Label the x-axis
    ax[0].set_ylabel("Frequency")  # Label the y-axis
    ax[0].legend([f"{j*10+16}-{j*10+26}" for j in range(0,7)])

    for j in range(0,2):
        gendergroup = df_all.loc[(df_all["Gender"] == j), var]
        ax[1].hist(gendergroup,alpha=0.4, density=True, bins=bins_specific[i])  # Plot the histogram on the axes
    ax[1].set_title(f"{i}: Histogram of {var} per gender group")  # Set the title
    ax[1].set_xlabel(var)  # Label the x-axis
    ax[1].set_ylabel("Frequency")  # Label the y-axis
    plt.show()
    plt.close(fig) # Closes the figure

# %%
# Group data by gender and age
age_gender_distribution = df_all.groupby(['Gender', 'Age']).size().unstack(fill_value=0)

# Normalize by the total count of each gender
normalized_distribution = age_gender_distribution #.div(age_gender_distribution.sum(axis=1), axis=0)

# Plot the normalized distribution with overlapping bars
plt.figure(figsize=(12, 6))
for gender in [0, 1]:  # Assuming 0 = Female, 1 = Male
    plt.bar(
        normalized_distribution.columns,
        normalized_distribution.loc[gender],
        alpha=0.5,
        label='Female' if gender == 0 else 'Male'
    )

plt.title('Normalized Age Group Distribution by Gender')
plt.xlabel('Age')
plt.ylabel('Proportion')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# # Data imputation - Q1.3

# %% [markdown]
# ### Data Scaling and Transformation

# %%
#TODO
#Try passing StandardScaler with_mean=False to avoid breaking the sparsity structure of the data
#Try PowerTransformer (Yeo-Johnson or Box-Cox) for TroponinI and TroponinT
#Try min-max scaling (0, 1) or robust scaling (median and IQR-based) for SaO2 and FiO2
#DON'T scale GSC (categorical encoding instead)
#Try two mixed normal distrubution for PaO2 (looks like a bimodal distribution)
#Try quantile transformation for age

# Fit scaler only on 'a'
df_a = pd.read_parquet("data_a_cleaned.parquet")

columns_for_log_transform = ['ALP', 'ALT', 'AST', 'Bilirubin', 'Creatinine', 'Urine', 'TroponinI', 'TroponinT',
                             'WBC', 'Platelets', 'Mg', 'Lactate', 'Glucose', 'BUN', 'DiasABP', 'K', 'PaO2']
df_a[columns_for_log_transform] = np.log(df_a[columns_for_log_transform] + 1e-9)
df_a['SaO2'] = np.log(df_a['SaO2'] / (100 - df_a['SaO2'] + 1e-9))

columns_to_scale = ['Age', 'Height', 'Weight', 'BUN', 'Creatinine', 'DiasABP', 'FiO2', 'GCS', 'Glucose', 'HCO3',
                    'HCT', 'HR', 'K', 'Lactate', 'MAP', 'Mg', 'NIDiasABP', 'NIMAP', 'NISysABP', 'Na', 'PaCO2', 'PaO2',
                    'Platelets', 'RespRate', 'SaO2', 'SysABP', 'Temp', 'Urine', 'WBC', 'pH', 'TroponinT', 'ALP', 'ALT',
                    'AST', 'Albumin', 'Bilirubin', 'Cholesterol', 'TroponinI']

scaler = StandardScaler()
scaler.fit(df_a[columns_to_scale])

# Apply transform to all
for letter in ["a", "b", "c"]:
    df = pd.read_parquet(f"data_{letter}_cleaned.parquet")

    df[columns_for_log_transform] = np.log(df[columns_for_log_transform] + 1e-9)
    df['SaO2'] = np.log(df['SaO2'] / (100 - df['SaO2'] + 1e-9))

    df[columns_to_scale] = scaler.transform(df[columns_to_scale])

    df.to_parquet(f"data_{letter}_scaled.parquet", engine="pyarrow", index=False)
    df.to_parquet(f"data_{letter}_scaled_nonImputed.parquet", engine="pyarrow", index=False)

# %% [markdown]
# Display Data

# %%
df = pd.read_parquet(f"data_a_scaled.parquet")
print(df.shape)
df.tail(10)
# Out:
# (196000, 44)
#         Time  RecordID       Age  Gender    Height  ICUType    Weight  \
# 195990    39  142673.0  0.783228     0.0 -1.121115      4.0  0.261788
# 195991    40  142673.0  0.783228     0.0 -1.121115      4.0  0.261788
# 195992    41  142673.0  0.783228     0.0 -1.121115      4.0  0.198866
# 195993    42  142673.0  0.783228     0.0 -1.121115      4.0  0.198866
# 195994    43  142673.0  0.783228     0.0 -1.121115      4.0  0.198866
# 195995    44  142673.0  0.783228     0.0 -1.121115      4.0  0.198866
# 195996    45  142673.0  0.783228     0.0 -1.121115      4.0  0.198866
# 195997    46  142673.0  0.783228     0.0 -1.121115      4.0  0.198866
# 195998    47  142673.0  0.783228     0.0 -1.121115      4.0  0.198866
# 195999    48  142673.0  0.783228     0.0 -1.121115      4.0  0.198866
#
#              BUN  Creatinine       GCS  Glucose      HCO3       HCT        HR  \
# 195990       NaN         NaN       NaN      NaN       NaN       NaN  0.352662
# 195991       NaN         NaN       NaN      NaN       NaN       NaN  0.465118
# 195992       NaN         NaN       NaN      NaN       NaN       NaN  0.296434
# 195993  0.193313    0.425907 -0.102789      NaN -0.875133  0.001677  0.633803
# 195994       NaN         NaN       NaN      NaN       NaN       NaN  0.971171
# 195995       NaN         NaN       NaN      NaN       NaN       NaN -0.040934
# 195996       NaN         NaN  0.905372      NaN       NaN       NaN -0.265847
# 195997       NaN         NaN  0.653332      NaN       NaN       NaN -0.097163
# 195998       NaN         NaN       NaN      NaN       NaN       NaN -0.040934
# 195999       NaN         NaN       NaN      NaN       NaN       NaN -0.153391
#
#          K        Mg  NIDiasABP     NIMAP  NISysABP       Na  Platelets  \
# 195990 NaN       NaN   0.054399 -0.075366  0.216447      NaN        NaN
# 195991 NaN       NaN  -1.215072 -1.292027 -0.436416      NaN        NaN
# 195992 NaN       NaN   0.588914 -0.142958 -0.856114      NaN        NaN
# 195993 NaN  0.278139   0.321656 -0.007773  0.123181  1.14347  -1.195766
# 195994 NaN       NaN   0.054399 -0.818881 -0.809481      NaN        NaN
# 195995 NaN       NaN   1.925199  0.870927  0.123181      NaN        NaN
# 195996 NaN       NaN  -0.212858 -0.954066 -0.856114      NaN        NaN
# 195997 NaN       NaN   1.591128  1.006111  0.029915      NaN        NaN
# 195998 NaN       NaN   0.588914  0.397780  0.636145      NaN        NaN
# 195999 NaN       NaN   0.522099  0.330188  0.449613      NaN        NaN
#
#         RespRate      Temp     Urine       WBC   DiasABP      FiO2       MAP  \
# 195990       NaN  0.928271 -0.007146       NaN -1.081446 -0.217382 -0.569078
# 195991       NaN  0.810064 -0.104518       NaN -1.405678       NaN -1.001154
# 195992       NaN  0.810064 -0.078924       NaN -0.047690       NaN -0.198727
# 195993       NaN  0.810064 -0.153042  0.012488  1.533129 -0.217382  0.356799
# 195994       NaN  0.810064 -0.122951       NaN -0.679939       NaN -0.507353
# 195995       NaN  0.691858 -0.175023       NaN -0.584485       NaN -0.322178
# 195996       NaN  0.573651 -0.175023       NaN -1.518689 -0.217382 -0.815979
# 195997       NaN       NaN -0.198838       NaN -0.777283       NaN -0.445628
# 195998       NaN  0.219031 -0.040786       NaN -0.398963       NaN -0.013552
# 195999       NaN       NaN -0.122951       NaN  0.036342       NaN  0.356799
#
#         MechVent     PaCO2      PaO2      SaO2    SysABP        pH       ALP  \
# 195990       1.0       NaN       NaN       NaN -0.539863       NaN       NaN
# 195991       NaN       NaN       NaN       NaN -0.985405       NaN       NaN
# 195992       NaN -0.816047 -0.918784 -0.263358 -0.539863  0.587590       NaN
# 195993       1.0       NaN       NaN       NaN  0.173004       NaN -1.193854
# 195994       NaN -0.154151 -0.199635 -0.144896 -0.628972 -0.338993       NaN
# 195995       NaN -0.043835 -0.114971  0.020340 -0.361646 -0.471362       NaN
# 195996       NaN       NaN       NaN       NaN -0.539863       NaN       NaN
# 195997       NaN       NaN       NaN       NaN -0.361646 -0.868470       NaN
# 195998       NaN       NaN       NaN       NaN  0.039342       NaN       NaN
# 195999       NaN       NaN       NaN       NaN  0.395776       NaN       NaN
#
#              ALT       AST   Albumin  Bilirubin   Lactate  Cholesterol  \
# 195990       NaN       NaN       NaN        NaN       NaN          NaN
# 195991       NaN       NaN       NaN        NaN       NaN          NaN
# 195992       NaN       NaN       NaN        NaN       NaN          NaN
# 195993 -1.229019  0.020079 -1.108532  -0.671326 -0.329401          NaN
# 195994       NaN       NaN       NaN        NaN       NaN          NaN
# 195995       NaN       NaN       NaN        NaN       NaN          NaN
# 195996       NaN       NaN       NaN        NaN       NaN          NaN
# 195997       NaN       NaN       NaN        NaN       NaN          NaN
# 195998       NaN       NaN       NaN        NaN       NaN          NaN
# 195999       NaN       NaN       NaN        NaN       NaN          NaN
#
#         TroponinI  TroponinT  In-hospital_death
# 195990        NaN        NaN                  0
# 195991        NaN        NaN                  0
# 195992        NaN        NaN                  0
# 195993        NaN        NaN                  0
# 195994        NaN        NaN                  0
# 195995        NaN        NaN                  0
# 195996        NaN        NaN                  0
# 195997        NaN        NaN                  0
# 195998        NaN        NaN                  0
# 195999        NaN        NaN                  0

# %% [markdown]
# Todo: Weird spikes above normal distribution, e.g. NISysABP, likely come from data imputation (adding repeated values). Maybe isnt ideal.

# %% [markdown]
# ### Imputation

# %%
## Forward fill TODO: maybe later different imputation and fill values that never come up (mean value)
# TODO: Doesnt it make more sense to scale after imputation?

def impute_missing_values(df):
    #This fills forward and then backward per RecordID, handling missing values at the start too.
    df_filled = df.groupby('RecordID').ffill().bfill()
    #then fills remaining all-NaN columns with the overall mean.
    return df.combine_first(df_filled).fillna(df.mean(numeric_only=True))

# %%
for letter in ["a", "b", "c"]:
    df = pd.read_parquet(f"data_{letter}_scaled.parquet")
    
    df = impute_missing_values(df)

    df.to_parquet(f"data_{letter}_scaled.parquet", engine="pyarrow", index=False)

# %%
df = pd.read_parquet(f"data_a_scaled.parquet")
df.head(50)
# Out:
#          ALP       ALT      AST       Age   Albumin       BUN  Bilirubin  \
# 0   0.542964  0.190212  0.57627 -0.583612 -0.341317 -0.650989   0.790529
#
.478029 -0.817074 -0.815979       1.0 -1.437983  -0.012415  0.938519
# 1   0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.012415  0.938519
# 2   0.478029 -0.817074 -0.815979       1.0 -1.437983   0.254842  0.668150
# 3   0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.413301 -0.097671
# 4   0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.413301 -0.300448
# 5   0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.413301 -0.300448
# 6   0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.881001 -0.706002
# 7   0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.881001 -0.706002
# 8   0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.613744 -0.593799
# 9   0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.146044 -0.391022
# 10  0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.680558 -0.480919
# 11  0.478029 -0.817074 -0.815979       1.0 -1.437983   0.254842  0.037513
# 12  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.215072 -1.134537
# 13  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.215072 -1.156842
# 14  0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.747372 -0.751289
# 15  0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.747372 -0.751289
# 16  0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.613744 -0.480919
# 17  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.215072 -1.246740
# 18  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.014629 -1.066945
# 19  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.014629 -1.066945
# 20  0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.212858 -0.165263
# 21  0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.212858 -0.165263
# 22  0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.947815 -0.931760
# 23  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.081444 -0.976371
# 24  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.148258 -1.043963
# 25  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.148258 -1.043963
# 26  0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.680558 -0.683696
# 27  0.478029 -0.817074 -0.815979       1.0 -1.437983  -0.680558 -0.683696
# 28  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.281886 -1.111556
# 29  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.281886 -1.111556
# 30  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.148258 -0.931760
# 31  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.148258 -0.931760
# 32  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.014629 -0.818881
# 33  0.478029 -0.817074 -0.815979       1.0 -1.437983  -1.014629 -0.818881
# 34 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.814186 -0.593799
# 35 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.814186 -0.593799
# 36 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.613744 -0.097671
# 37 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.613744 -0.097671
# 38 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.747372 -0.458614
# 39 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.747372 -0.458614
# 40 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.079229  0.105106
# 41 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.346486 -0.345735
# 42 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.546929 -0.503225
# 43 -0.129833 -0.817074 -0.815979       1.0 -0.232320   0.588914  0.713436
# 44 -0.129833 -0.817074 -0.815979       1.0 -0.232320   0.388471  0.375475
# 45 -0.129833 -0.817074 -0.815979       1.0 -0.232320   0.388471  0.375475
# 46 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.146044  0.284901
# 47 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.146044  0.284901
# 48 -0.129833 -0.817074 -0.815979       1.0 -0.232320  -0.212858  0.149717
# 49  0.331408 -0.817074 -0.815979       1.0  2.264541   0.455285  0.622863
#
#     NISysABP        Na     PaCO2      PaO2  Platelets  RecordID  RespRate  \
# 0   1.755339 -0.399351 -0.705731  1.982299   0.513567  132539.0 -0.121643
# 1   1.755339 -0.399351 -0.705731  1.982299   0.513567  132539.0 -0.121643
# 2   0.822677 -0.399351 -0.705731  1.982299   0.513567  132539.0 -0.304259
# 3   0.169814 -0.399351 -0.705731  1.982299   0.513567  132539.0 -0.121643
# 4  -0.249884 -0.399351 -0.705731  1.982299   0.513567  132539.0  0.060973
# 5  -0.249884 -0.399351 -0.705731  1.982299   0.513567  132539.0  0.060973
# 6  -0.436416 -0.399351 -0.705731  1.982299   0.513567  132539.0 -0
# 40  0.299877 -1.163622  0.928271    40  -0.589991  -1.197795  0.650493
# 41  0.299877 -1.163622  0.928271    41  -0.589991  -1.197795  0.650493
# 42  0.299877 -1.163622  0.928271    42  -0.589991  -1.197795  0.650493
# 43  0.299877 -1.163622  0.928271    43  -0.589991  -1.197795  0.650493
# 44  0.299877 -1.163622  0.573651    44  -0.589991  -1.197795  0.482616
# 45  0.299877 -1.163622  0.573651    45  -0.589991  -1.197795  0.482616
# 46  0.299877 -1.163622  0.573651    46  -0.589991  -1.197795  0.534689
# 47  0.299877 -1.163622  0.573651    47  -0.589991  -1.197795  0.534689
# 48  0.299877 -1.163622  0.810064    48  -0.589991  -1.197795  0.514984
# 49  0.299877 -1.163622 -2.736134     0  -0.589991  -1.197795  0.388792
#
#          WBC    Weight        pH
# 0   0.042486 -0.275151  0.984697
# 1   0.042486 -0.275151  0.984697
# 2   0.042486 -0.275151  0.984697
# 3   0.042486 -0.275151  0.984697
# 4   0.042486 -0.275151  0.984697
# 5   0.042486 -0.275151  0.984697
# 6   0.042486 -0.275151  0.984697
# 7   0.042486 -0.275151  0.984697
# 8   0.042486 -0.275151  0.984697
# 9   0.042486 -0.275151  0.984697
# 10  0.042486 -0.275151  0.984697
# 11  0.042486 -0.275151  0.984697
# 12  0.042486 -0.275151  0.984697
# 13  0.042486 -0.275151  0.984697
# 14  0.042486 -0.275151  0.984697
# 15  0.042486 -0.275151  0.984697
# 16  0.042486 -0.275151  0.984697
# 17  0.042486 -0.275151  0.984697
# 18  0.042486 -0.275151  0.984697
# 19  0.042486 -0.275151  0.984697
# 20  0.042486 -0.275151  0.984697
# 21  0.042486 -0.275151  0.984697
# 22  0.042486 -0.275151  0.984697
# 23  0.042486 -0.275151  0.984697
# 24  0.042486 -0.275151  0.984697
# 25  0.042486 -0.275151  0.984697
# 26  0.042486 -0.275151  0.984697
# 27  0.042486 -0.275151  0.984697
# 28  0.042486 -0.275151  0.984697
# 29  0.042486 -0.275151  0.984697
# 30  0.042486 -0.275151  0.984697
# 31  0.042486 -0.275151  0.984697
# 32  0.042486 -0.275151  0.984697
# 33  0.042486 -0.275151  0.984697
# 34 -0.249204 -0.275151  0.984697
# 35 -0.249204 -0.275151  0.984697
# 36 -0.249204 -0.275151  0.984697
# 37 -0.249204 -0.275151  0.984697
# 38 -0.249204 -0.275151  0.984697
# 39 -0.249204 -0.275151  0.984697
# 40 -0.249204 -0.275151  0.984697
# 41 -0.249204 -0.275151  0.984697
# 42 -0.249204 -0.275151  0.984697
# 43 -0.249204 -0.275151  0.984697
# 44 -0.249204 -0.275151  0.984697
# 45 -0.249204 -0.275151  0.984697
# 46 -0.249204 -0.275151  0.984697
# 47 -0.249204 -0.275151  0.984697
# 48 -0.249204 -0.275151  0.984697
# 49 -0.647487 -0.275151  0.984697

# %% [markdown]
# ### Display imputed/scaled/transformed data

# %%
plot_histograms(bins_general, "scaled")

# %% [markdown]
# <span style="font-size:25px"><strong>Code for the next tasks is in the other files!</strong></span>
